# %%
import pandas as pd
import numpy as np
import os

# %%
# !ls '../files/'
# Out:
# image_labels.csv           train_baseline_helmets.csv
# sample_submission.csv      train_labels.csv
# test_baseline_helmets.csv  train_player_tracking.csv
# test_player_tracking.csv

# %%
# image label dataset
image_labels = pd.read_csv('../files/image_labels.csv')

path_to_save = '../dataset/labels/'

# %%
image_labels.head()
# Out:
#                                image   label  left  width  top  height
# 0  57503_000116_Endzone_frame443.jpg  Helmet  1099     16  456      15
# 1  57503_000116_Endzone_frame443.jpg  Helmet  1117     15  478      16
# 2  57503_000116_Endzone_frame443.jpg  Helmet   828     16  511      15
# 3  57503_000116_Endzone_frame443.jpg  Helmet   746     16  519      16
# 4  57503_000116_Endzone_frame443.jpg  Helmet   678     17  554      17

# %%
image_labels[image_labels.label != 'helmet']
# Out:
#                                      image   label  left  width  top  height
# 0        57503_000116_Endzone_frame443.jpg  Helmet  1099     16  456      15
# 1        57503_000116_Endzone_frame443.jpg  Helmet  1117     15  478      16
# 2        57503_000116_Endzone_frame443.jpg  Helmet   828     16  511      15
# 3        57503_000116_Endzone_frame443.jpg  Helmet   746     16  519      16
# 4        57503_000116_Endzone_frame443.jpg  Helmet   678     17  554      17
# ...                                    ...     ...   ...    ...  ...     ...
# 193731  58167_003154_Endzone_frame0808.jpg  Helmet   928     29  549      23
# 193732  58167_003154_Endzone_frame0808.jpg  Helmet  1149     25  278      23
# 193733  58167_003154_Endzone_frame0808.jpg  Helmet   839     31  663      29
# 193734  58167_003154_Endzone_frame0808.jpg  Helmet   918     29  680      25
# 193735  58167_003154_Endzone_frame0808.jpg  Helmet  1090     26  688      25
#
# [193736 rows x 6 columns]

# %%
image_labels.head()
# Out:
#                                image   label  left  width  top  height
# 0  57503_000116_Endzone_frame443.jpg  Helmet  1099     16  456      15
# 1  57503_000116_Endzone_frame443.jpg  Helmet  1117     15  478      16
# 2  57503_000116_Endzone_frame443.jpg  Helmet   828     16  511      15
# 3  57503_000116_Endzone_frame443.jpg  Helmet   746     16  519      16
# 4  57503_000116_Endzone_frame443.jpg  Helmet   678     17  554      17

# %%
image_labels.replace('^Helmet', 0, inplace=True, regex=True)

# %%
image_labels.head()
# Out:
#                                image label      left     width       top  \
# 0  57503_000116_Endzone_frame443.jpg     0  0.858594  0.012500  0.633333
# 1  57503_000116_Endzone_frame443.jpg     0  0.872656  0.011719  0.663889
# 2  57503_000116_Endzone_frame443.jpg     0  0.646875  0.012500  0.709722
# 3  57503_000116_Endzone_frame443.jpg     0  0.582812  0.012500  0.720833
# 4  57503_000116_Endzone_frame443.jpg     0  0.529687  0.013281  0.769444
#
#      height
# 0  0.020833
# 1  0.022222
# 2  0.020833
# 3  0.022222
# 4  0.023611

# %%
# normalize labels

imgHeight = 720
imgWidth = 1280

image_labels.top /= imgHeight
image_labels.height /= imgHeight
image_labels.left /= imgWidth
image_labels.width /= imgWidth

# %%
image_labels.head()
# Out:
#                                image label      left     width       top  \
# 0  57503_000116_Endzone_frame443.jpg     0  0.858594  0.012500  0.633333
# 1  57503_000116_Endzone_frame443.jpg     0  0.872656  0.011719  0.663889
# 2  57503_000116_Endzone_frame443.jpg     0  0.646875  0.012500  0.709722
# 3  57503_000116_Endzone_frame443.jpg     0  0.582812  0.012500  0.720833
# 4  57503_000116_Endzone_frame443.jpg     0  0.529687  0.013281  0.769444
#
#      height
# 0  0.020833
# 1  0.022222
# 2  0.020833
# 3  0.022222
# 4  0.023611

# %%
#helmet is label 0
#so the txt file have every entry as 0 followed by x_center y_center width height
fileBeingProcess = ''
indexToBeTxt = []
savePath = '../dataset/labels/'

for imageFile, index in zip(image_labels.image, image_labels.index):
    
    if fileBeingProcess == '':
        fileBeingProcess = imageFile
        
    if imageFile == fileBeingProcess:
        indexToBeTxt.append(index)
    else:
        fileName = fileBeingProcess.replace('.jpg', '.txt')
        
        fileBeingProcess = imageFile
        
        dataToTxt = image_labels.loc[indexToBeTxt]
        dataToTxt.drop('image', axis=1, inplace = True)
        dataToTxt.to_csv(os.path.join(savePath, fileName), sep='\t', index=False, header=False)
        
        indexToBeTxt = []
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/jn/ck8kvq0d4h7bjzszjkxcp7tw0000gn/T/ipykernel_2262/2352728258.py in <module>
#      19         dataToTxt = image_labels.loc[indexToBeTxt]
#      20         dataToTxt.drop('image', axis=1, inplace = True)
# ---> 21         dataToTxt.to_csv(os.path.join(savePath, fileName), sep='\t', index=False, header=False)
#      22
#      23         indexToBeTxt = []
#
# ~/Documents/projects/nfl-helmet-assignment/nfl-kaggle/lib/python3.8/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~/Documents/projects/nfl-helmet-assignment/nfl-kaggle/lib/python3.8/site-packages/pandas/io/formats/format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1076         Render dataframe as comma-separated file.
#    1077         """
# -> 1078         from pandas.io.formats.csvs import CSVFormatter
#    1079
#    1080         if path_or_buf is None:
#
# KeyboardInterrupt:

# %%
'Helmet-Blurred'
image_labels[image_labels.label == 'Helmet-Blurred']
# Out:
#                                       image           label      left  \
# 20        57503_000116_Endzone_frame443.jpg  Helmet-Blurred  0.542969
# 21        57503_000116_Endzone_frame443.jpg  Helmet-Blurred  0.507031
# 22       57503_000116_Sideline_frame490.jpg  Helmet-Blurred  0.307812
# 23       57503_000116_Sideline_frame490.jpg  Helmet-Blurred  0.365625
# 24       57503_000116_Sideline_frame490.jpg  Helmet-Blurred  0.294531
# ...                                     ...             ...       ...
# 193702  58167_002809_Sideline_frame1804.jpg  Helmet-Blurred  0.612500
# 193703  58167_002809_Sideline_frame1804.jpg  Helmet-Blurred  0.567187
# 193704  58167_002809_Sideline_frame1804.jpg  Helmet-Blurred  0.252344
# 193717   58167_002854_Endzone_frame0799.jpg  Helmet-Blurred  0.711719
# 193718   58167_002854_Endzone_frame0799.jpg  Helmet-Blurred  0.217188
#
#            width       top    height
# 20      0.009375  0.309722  0.020833
# 21      0.007031  0.620833  0.015278
# 22      0.007812  0.477778  0.018056
# 23      0.008594  0.401389  0.016667
# 24      0.007031  0.373611  0.016667
# ...          ...       ...       ...
# 193702  0.006250  0.263889  0.011111
# 193703  0.005469  0.254167  0.011111
# 193704  0.005469  0.251389  0.011111
# 193717  0.014844  0.298611  0.030556
# 193718  0.021875  0.451389  0.031944
#
# [33544 rows x 6 columns]
